# %%
import sys
import os
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")  # This will help us verify the path
sys.path.append(project_root)
# Out:
# Project root: c:\Users\tsega\Desktop\news-sentiment-stock-prediction

# %%
import sys
import os
# Add the scripts directory directly to the path
scripts_path = os.path.join(project_root, 'scripts')
sys.path.append(scripts_path)

# Now try importing
print(f"Scripts path: {scripts_path}")

# Import and verify the class
from eda_task1 import EDA
print("EDA class methods:", [method for method in dir(EDA) if not method.startswith('_')])
import pandas as pd
# Out:
# Scripts path: c:\Users\tsega\Desktop\news-sentiment-stock-prediction\scripts
# EDA class methods: ['basic_summary', 'descriptive_statistics', 'get_cleaned_news', 'publisher_analysis', 'text_topic_modeling', 'time_series_analysis']

# %%
df = pd.read_csv("./../data/raw_analyst_ratings.csv")

# %%
import importlib
import eda_task1
importlib.reload(eda_task1)
from eda_task1 import EDA

# Now create the instance
eda = EDA(df)
eda.basic_summary()
# Out:
#  DataFrame Shape: (1407328, 6)
#
#  Columns: ['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock']
#
#  Data Types:
#  Unnamed: 0                        int64
# headline                         object
# url                              object
# publisher                        object
# date          datetime64[ns, UTC-04:00]
# stock                            object
# dtype: object
#
#  Missing Values Summary:
#             Missing Values  % of Total
# date               1351341   96.021752
# Unnamed: 0               0    0.000000
# headline                 0    0.000000
# url                      0    0.000000
# publisher                0    0.000000
# stock                    0    0.000000
#
#  Descriptive Statistics:
#            Unnamed: 0                 headline  \
# count   1.407328e+06                  1407328
# unique           NaN                   845770
# top              NaN  Benzinga's Top Upgrades
# freq             NaN                     5449
# ...

# %%
eda.descriptive_statistics()
# Out:
#  Basic Descriptive Stats
#
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64
#
#  Top 10 Most Active Publishers
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64
#
#  Articles Published Over Time

# %%
eda.text_topic_modeling()
# Out:
# 🔹 Topic Modeling
#
#
# Topic #1:
# ['10', '2019', '2018', 'etf', 'watch', 'etfs', 'scheduled', 'benzinga', 'stocks', 'earnings']
#
# Topic #2:
# ['52', 'lower', 'stock', 'week', 'higher', 'companies', 'says', 'stocks', 'trading', 'shares']
#
# Topic #3:
# ['target', 'maintains', 'raises', 'buy', 'pt', 'sales', 'reports', 'eps', 'est', 'vs']
#
# Topic #4:
# ['low', 'highest', 'set', 'industry', 'reports', '52', 'week', 'announces', 'stocks', 'new']
#
# Topic #5:
# ['downgrades', 'biggest', 'benzinga', 'day', 'moving', 'session', 'update', 'stocks', 'mid', 'market']

# %%
import importlib
import eda_task1
importlib.reload(eda_task1)
from eda_task1 import EDA

# Now create the instance
eda = EDA(df)

eda.time_series_analysis()
# Out:
# [INFO] Performing time series analysis...
# c:\Users\tsega\Desktop\news-sentiment-stock-prediction\scripts\eda_task1.py:83: UserWarning: Glyph 128197 (\N{CALENDAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\tsega\Desktop\news-sentiment-stock-prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128197 (\N{CALENDAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\tsega\Desktop\news-sentiment-stock-prediction\scripts\eda_task1.py:97: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\tsega\Desktop\news-sentiment-stock-prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# [INFO] Time series analysis completed successfully.

# %%
eda.publisher_analysis()
# Out:
# 🔹 Publisher Analysis

# %%
eda.get_cleaned_news()
cleaned_news = eda.get_cleaned_news()
cleaned_news.to_csv("./../data/cleaned_news.csv", index=False)
