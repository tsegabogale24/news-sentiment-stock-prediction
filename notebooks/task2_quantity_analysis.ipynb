# %%
import sys
import os
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")  # This will help us verify the path
sys.path.append(project_root)
# Out:
# Project root: c:\Users\tsega\Desktop\news-sentiment-stock-prediction

# %%
import sys
import os
# Add the scripts directory directly to the path
scripts_path = os.path.join(project_root, 'scripts')
sys.path.append(scripts_path)

# Now try importing
print(f"Scripts path: {scripts_path}")

# Import and verify the class
from quantity_analysis import QuantitativeAnalysis

import pandas as pd
# Out:
# Scripts path: c:\Users\tsega\Desktop\news-sentiment-stock-prediction\scripts

# %%
import importlib
import quantity_analysis
importlib.reload(quantity_analysis)
from quantity_analysis import QuantitativeAnalysis

qa = QuantitativeAnalysis("AAPL")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for AAPL
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for AAPL ---
# P/E Ratio: 31.14486
# Market Cap: 2993431511040

# %%
qa = QuantitativeAnalysis("AMZN")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for AMZN
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for AMZN ---
# P/E Ratio: 33.55628
# Market Cap: 2183793475584

# %%
qa = QuantitativeAnalysis("GOOG")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for GOOG
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for GOOG ---
# P/E Ratio: 19.303572
# Market Cap: 2091484315648

# %%
qa = QuantitativeAnalysis("META")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for META
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for META ---
# P/E Ratio: 25.187426
# Market Cap: 1621868544000

# %%
qa = QuantitativeAnalysis("MSFT")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for MSFT
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for MSFT ---
# P/E Ratio: 35.47409
# Market Cap: 3409157554176

# %%
qa = QuantitativeAnalysis("NVDA")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for NVDA
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for NVDA ---
# P/E Ratio: 44.9
# Market Cap: 3394510258176

# %%
qa = QuantitativeAnalysis("TSLA")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for TSLA
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for TSLA ---
# P/E Ratio: 203.65341
# Market Cap: 1154488729600
