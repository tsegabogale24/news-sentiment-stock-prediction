# %%
import sys
import os
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")  # This will help us verify the path
sys.path.append(project_root)
# Out:
# Project root: c:\Users\tsega\Desktop\news-sentiment-stock-prediction

# %%
import sys
sys.path.append('../scripts')  # Add scripts directory to Python path

from quantity_analysis import QuantitativeAnalysis

# %%
import importlib
import quantity_analysis
importlib.reload(quantity_analysis)
from quantity_analysis import QuantitativeAnalysis

qa = QuantitativeAnalysis("AAPL")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
qa.save_to_csv()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for AAPL
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for AAPL ---
# Current Price:       201.01
# P/E Ratio:           31.256113
# Earnings Per Share:  6.43
# Market Cap:          3001749340160
# 52 Week High:        260.1
# 52 Week Low:         169.21
# Dividend Yield:      0.52
# Data saved to ./../data/stock_data.csv

# %%
qa = QuantitativeAnalysis("AMZN")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for AMZN
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for AMZN ---
# Current Price:       205.01
# P/E Ratio:           33.443718
# Earnings Per Share:  6.13
# Market Cap:          2176468123648
# 52 Week High:        242.52
# 52 Week Low:         151.61
# Dividend Yield:      N/A

# %%
qa = QuantitativeAnalysis("GOOG")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for GOOG
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for GOOG ---
# Current Price:       172.85
# P/E Ratio:           19.31285
# Earnings Per Share:  8.95
# Market Cap:          2090084990976
# 52 Week High:        208.7
# 52 Week Low:         142.66
# Dividend Yield:      0.49

# %%
qa = QuantitativeAnalysis("META")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for META
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for META ---
# Current Price:       647.49
# P/E Ratio:           25.312353
# Earnings Per Share:  25.58
# Market Cap:          1628003631104
# 52 Week High:        740.91
# 52 Week Low:         442.65
# Dividend Yield:      0.32

# %%
qa = QuantitativeAnalysis("MSFT")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for MSFT
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for MSFT ---
# Current Price:       460.36
# P/E Ratio:           35.576508
# Earnings Per Share:  12.94
# Market Cap:          3421643997184
# 52 Week High:        468.35
# 52 Week Low:         344.79
# Dividend Yield:      0.72

# %%
qa = QuantitativeAnalysis("NVDA")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for NVDA
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for NVDA ---
# Current Price:       135.13
# P/E Ratio:           43.731396
# Earnings Per Share:  3.09
# Market Cap:          3295496634368
# 52 Week High:        153.13
# 52 Week Low:         86.62
# Dividend Yield:      0.03

# %%
qa = QuantitativeAnalysis("TSLA")
qa.load_data()
qa.compute_indicators()
qa.financial_metrics()
qa.visualize()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data loaded for TSLA
# Indicators computed: SMA_20, RSI, MACD
# --- Financial Metrics for TSLA ---
# Current Price:       346.46
# P/E Ratio:           195.74011
# Earnings Per Share:  1.77
# Market Cap:          1115933769728
# 52 Week High:        488.54
# 52 Week Low:         167.41
# Dividend Yield:      N/A
